# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ## Scikit-Learn

# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV

# %% [markdown]
# ## Pre-Processed Data

# %%
from datasets import get_data
X, X_0, Y = get_data()

# %%
X
#X = X.ix[:, 4:10]
# Out:
#      City  City Group  Type  P1   P2   P3   P4  P5  P6  P7  ...   P31  P32  \
# 0      60           0     2   4  5.0  4.0  4.0   2   2   5  ...     3    4
# 1       4           0     1   4  5.0  4.0  4.0   1   2   5  ...     0    0
# 2      14           1     2   2  4.0  2.0  5.0   2   3   5  ...     0    0
# 3      52           1     2   6  4.5  6.0  6.0   4   4  10  ...    12   10
# 4      21           1     2   3  4.0  3.0  4.0   2   2   5  ...     1    3
# 5       4           0     1   6  6.0  4.5  7.5   8  10  10  ...     0    0
# 6      60           0     2   2  3.0  4.0  4.0   1   5   5  ...     5    2
# 7      60           0     2   4  5.0  4.0  5.0   2   3   5  ...     0    0
# 8       1           1     2   1  1.0  4.0  4.0   1   2   1  ...     5    5
# 9      16           1     2   6  4.5  6.0  7.5   6   4  10  ...     0    0
# 10     30           1     1   9  6.0  6.0  6.0   4   4  10  ...     0    0
# 11     60           0     2   2  4.0  4.0  4.0   2   5   5  ...     5    4
# 12      4           0     2   2  2.0  4.0  4.0   2   1   5  ...     0    0
# 13     60           0     1   4  5.0  4.0  4.0   1   3   5  ...     0    0
# 14     12           1     1   2  2.0  4.0  4.0   1   2   5  ...     0    0
# 15     60           0     2  12  7.5  6.0  6.0   2  10  10  ...    15   20
# 16     60           0     1   3  5.0  4.0  4.0   2   5   5  ...     0    0
# 17     60           0     1   2  4.0  4.0  5.0   1   3   5  ...     0    0
# 18     61           0     2   4  5.0  4.0  3.0   1   2   5  ...     5    5
# 19     46           1     2   2  4.0  4.0  4.0   2   2   5  ...     0    0
# 20     17           1     2   3  4.0  4.0  4.0   2   2   5  ...     1    2
# 21     60           0     1   5  5.0  4.0  4.0   2   2   5  ...     0    0
# 22     29           1     1   9  6.0  6.0  6.0   4   6  10  ...     0    0
# 23     46           1     1   2  4.0  4.0  4.0   2   2   5  ...     0    0
# 24     60           0     2   5  5.0  3.0  5.0   2   2   5  ...     5    4
# 25     20           1     1   4  4.0  5.0  5.0   2   2   5  ...     0    0
# 26      4           0     2   3  5.0  4.0  5.0   2   3   5  ...     5    4
# 27     12           1     1   4  5.0  4.0  3.0   1   2   5  ...     0    0
# 28     60           0     2   4  5.0  4.0  4.0   1   3   5  ...     5    5
# 29      4           0     1   1  1.0  4.0  4.0   2   1   1  ...     0    0
# ..    ...         ...   ...  ..  ...  ...  ...  ..  ..  ..  ...   ...  ...
# 107    47           1     2   4  4.0  4.0  4.0   1   2   5  ...     5    5
# 108    40           1     1   1  2.0  5.0  4.0   1   2   1  ...     0    0
# 109     4           0     1   2  4.0  3.0  5.0   4   5   5  ...     0    0
# 110     3           1     2   6  3.0  6.0  6.0   4   4  10  ...     3   15
# 111    32           1     1   2  3.0  4.0  4.0   2   1   5  ...     0    0
# 112    60           0     2   4  5.0  5.0  4.0   1   5   5  ...     2    1
# 113    51           1     1   3  4.0  4.0  4.0   1   2   5  ...     0    0
# 114    20           1     2   4  5.0  5.0  4.0   2   2   5  ...     3    3
# 115    60           0     2   6  4.5  6.0  6.0   4   8  10  ...    15   25
# 116    61           0     1   2  4.0  4.0  4.0   2   2   5  ...     0    0
# 117     4           0     2   3  5.0  4.0  5.0   3   3   5  ...     3    3
# 118    60           0     2  12  7.5  7.5  4.5   2  10  10  ...     6   10
# 119    60           0     2   4  5.0  4.0  4.0   2   3   5  ...     0    0
# 120     7           1     1   2  3.0  4.0  4.0   2   2   5  ...     0    0
# 121    61           0     1   2  4.0  4.0  4.0   2   3   5  ...     0    0
# 122    60           0     2  12  7.5  6.0  7.5   2   8  10  ...    15   25
# 123    11           1     1   1  1.0  4.0  3.0   1   1   1  ...     0    0
# 124     4           0     0   1  3.0  0.0  5.0   5   5   1  ...     0    0
# 125    53           1     2   9  6.0  6.0  6.0   4   6  10  ...     9   15
# 126    24           1     2   3  3.0  4.0  4.0   2   2   5  ...     5    5
# 127    12           1     1   3  4.0  4.0  4.0   2   2   5  ...     0    0
# 128     4           0     1   2  4.0  4.0  4.0   1   2   5  ...     0    0
# 129    20           1     1   4  5.0  5.0  4.0   2   2   5  ...     0    0
# 130    44           1     1   3  4.0  3.0  4.0   2   1   5  ...     0    0
# 131     4           0     1   3  4.0  4.0  5.0   3   4   5  ...     0    0
# 132    53           1     1   2  3.0  3.0  5.0   4   2   4  ...     0    0
# 133    61           0     1   4  5.0  4.0  4.0   2   3   5  ...     0    0
# 134    29           1     1   3  4.0  4.0  4.0   2   3   5  ...     0    0
# 135    60           0     1   4  5.0  4.0  5.0   2   2   5  ...     0    0
# 136    60           0     1   4  5.0  3.0  5.0   2   2   5  ...     0    0
#
#      P33  P34  P35  P36  P37  Year  Month  Week
# 0      5    5    4    3    4  1999      7    28
# 1      0    0    0    0    0  2008      2     7
# 2      0    0    0    0    0  2013      3    10
# 3      6   18   12   12    6  2012      2     5
# 4      2    3    4    3    3  2009      5    19
# 5      0    0    0    0    0  2010      2     6
# 6      2    3    5    4    4  2010     10    41
# 7      0    0    0    0    0  2011      6    25
# 8      3    4    5    4    5  2010      8    34
# 9      0    0    0    0    0  2011     11    46
# 10     0    0    0    0    0  2013      8    32
# 11     2    3    4    4    2  2012      5    21
# 12     0    0    0    0    0  2013      2     9
# 13     0    0    0    0    0  2010     10    41
# 14     0    0    0    0    0  2011     12    52
# 15     2   12    3   16    4  2012      2     6
# 16     0    0    0    0    0  2000      1     1
# 17     0    0    0    0    0  2009     11    45
# 18     4    4    4    3    2  2012      4    16
# 19     0    0    0    0    0  2011      8    33
# 20     2    4    5    5    4  2010      8    34
# 21     0    0    0    0    0  2014      1     4
# 22     0    0    0    0    0  2006      7    26
# 23     0    0    0    0    0  2009      6    23
# 24     4    4    4    5    2  2009      9    38
# 25     0    0    0    0    0  2011     12    51
# 26     3    3    4    3    1  2010      2     8
# 27     0    0    0    0    0  1999     10    40
# 28     2    3    5    4    4  1998      1     5
# 29     0    0    0    0    0  2006     10    41
# ..   ...  ...  ...  ...  ...   ...    ...   ...
# 107    3    4    4    4    3  2011      5    17
# 108    0    0    0    0    0  2012      7    28
# 109    0    0    0    0    0  2007      8    34
# 110    6   18   12   16    6  2012      9    39
# 111    0    0    0    0    0  2012      8    32
# 112    2    2    1    3    3  1998      3    11
# 113    0    0    0    0    0  2006     12    49
# 114    2    3    4    3    1  2008     12    49
# 115    4   18   12   16    8  2012      5    18
# 116    0    0    0    0    0  2012      3    13
# 117    2    3    4    3    1  2005     12    52
# 118    4   18   12   12    2  2009     12    52
# 119    0    0    0    0    0  2014      1     1
# 120    0    0    0    0    0  2011      8    33
# 121    0    0    0    0    0  2004     11    46
# 122    6   18    3   16    6  1997      4    15
# 123    0    0    0    0    0  2011     11    44
# 124    0    0    0    0    0  2005      8    33
# 125    4   24   12   16    2  2010      9    35
# 126    4    2    5    3    2  2008      7    29
# 127    0    0    0    0    0  2007      9    36
# 128    0    0    0    0    0  2011     10    41
# 129    0    0    0    0    0  2007      2     6
# 130    0    0    0    0    0  2011     10    43
# 131    0    0    0    0    0  2002     11    45
# 132    0    0    0    0    0  2008      6    26
# 133    0    0    0    0    0  2006     10    41
# 134    0    0    0    0    0  2006      7    27
# 135    0    0    0    0    0  2010     10    43
# 136    0    0    0    0    0  2009      9    36
#
# [137 rows x 43 columns]

# %% [markdown]
# ### Principle Components Analysis

# %%
n_components = [3, 4, 5]

pca = PCA()
logistic = LogisticRegression()
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

estimator = GridSearchCV(pipe,
                         dict( \
                              pca__n_components=n_components, \
                             ))
estimator.fit(X, Y)

plt.axvline(estimator.best_estimator_.named_steps['pca'].n_components,
            linestyle=':', label='n_components chosen')
plt.legend(prop=dict(size=12))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6c343fc6cbbf> in <module>()
#       9                               pca__n_components=n_components, \
#      10                              ))
# ---> 11 estimator.fit(X, Y)
#      12
#      13 plt.axvline(estimator.best_estimator_.named_steps['pca'].n_components,
#
# C:\tools\Miniconda\lib\site-packages\sklearn\grid_search.pyc in fit(self, X, y)
#     730
#     731         """
# --> 732         return self._fit(X, y, ParameterGrid(self.param_grid))
#     733
#     734
#
# C:\tools\Miniconda\lib\site-packages\sklearn\grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     503                                     self.fit_params, return_parameters=True,
#     504                                     error_score=self.error_score)
# --> 505                 for parameters in parameter_iterable
#     506                 for train, test in cv)
#     507
#
# C:\tools\Miniconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     657             self._iterating = True
#     658             for function, args, kwargs in iterable:
# --> 659                 self.dispatch(function, args, kwargs)
#     660
#     661             if pre_dispatch == "all" or n_jobs == 1:
#
# C:\tools\Miniconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch(self, func, args, kwargs)
#     404         """
#     405         if self._pool is None:
# --> 406             job = ImmediateApply(func, args, kwargs)
#     407             index = len(self._jobs)
#     408             if not _verbosity_filter(index, self.verbose):
#
# C:\tools\Miniconda\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, func, args, kwargs)
#     138         # Don't delay the application, to avoid keeping the input
#     139         # arguments in memory
# --> 140         self.results = func(*args, **kwargs)
#     141
#     142     def get(self):
#
# C:\tools\Miniconda\lib\site-packages\sklearn\cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1457             estimator.fit(X_train, **fit_params)
#    1458         else:
# -> 1459             estimator.fit(X_train, y_train, **fit_params)
#    1460
#    1461     except Exception as e:
#
# C:\tools\Miniconda\lib\site-packages\sklearn\pipeline.pyc in fit(self, X, y, **fit_params)
#     138             the pipeline.
#     139         """
# --> 140         Xt, fit_params = self._pre_transform(X, y, **fit_params)
#     141         self.steps[-1][-1].fit(Xt, y, **fit_params)
#     142         return self
#
# C:\tools\Miniconda\lib\site-packages\sklearn\pipeline.pyc in _pre_transform(self, X, y, **fit_params)
#     119         for name, transform in self.steps[:-1]:
#     120             if hasattr(transform, "fit_transform"):
# --> 121                 Xt = transform.fit_transform(Xt, y, **fit_params_steps[name])
#     122             else:
#     123                 Xt = transform.fit(Xt, y, **fit_params_steps[name]) \
#
# C:\tools\Miniconda\lib\site-packages\sklearn\decomposition\pca.pyc in fit_transform(self, X, y)
#     236
#     237         """
# --> 238         U, S, V = self._fit(X)
#     239         U = U[:, :self.n_components_]
#     240
#
# C:\tools\Miniconda\lib\site-packages\sklearn\decomposition\pca.pyc in _fit(self, X)
#     263             requested.
#     264         """
# --> 265         X = check_array(X)
#     266         n_samples, n_features = X.shape
#     267         X = as_float_array(X, copy=self.copy)
#
# C:\tools\Miniconda\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features)
#     352             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     353                              " minimum of %d is required."
# --> 354                              % (n_samples, shape_repr, ensure_min_samples))
#     355
#     356
#
# ValueError: Found array with 0 sample(s) (shape=(0, 43)) while a minimum of 1 is required.

# %%
pca = PCA(n_components=7)
train_pca = pca.fit_transform(attr)
print pca.explained_variance_ratio_

test_pca = pca.transform(test_attr)
# Out:
# [ 0.49584207  0.22271101  0.17536295  0.04558604  0.01481238  0.00850373
#   0.00564627]

# %%
train_pca_0 = pca.inverse_transform(train_pca)
test_pca_0 = pca.inverse_transform(test_pca)

plt.scatter(train_pca[:, 0], train_pca[:, 1], c='b')
plt.scatter(train_pca_0[:, 0], train_pca_0[:, 1], c='r')
#plt.scatter(test_pca[:, 0], test_pca[:, 1], c='k')
#plt.scatter(test_pca_0[:, 0], test_pca_0[:, 1], c='g')

# %% [markdown]
# ### Linear Regression and Cross Validation

# %%
from sklearn.cross_validation import train_test_split, KFold, StratifiedKFold
kf = KFold(len(attr), n_folds=6)
skf = StratifiedKFold(attr.ix[0])
X_train, X_test, y_train, y_test = train_test_split(train_pca, target)

# %%
from sklearn.svm import SVR
svr = SVR()
svr_pca = SVR()
scores = [svr.fit(attr.ix[train], target[train]).score(attr.ix[test], target[test])
          for train, test in kf]
scores_pca = [svr_pca.fit(train_pca[train], target[train]).score(train_pca[test], target[test])
          for train, test in kf_pca]

# %%
from sklearn.linear_model import LinearRegression, ElasticNetCV, OrthogonalMatchingPursuitCV, LarsCV
from sklearn.ensemble import ExtraTreesRegressor

etr = ExtraTreesRegressor(n_estimators=100, max_features=2)
lr = LinearRegression()
omp = OrthogonalMatchingPursuitCV()

etr.fit(train_pca, target)

predicted_train = etr.predict(X_train)
predicted_test = etr.predict(X_test)
print etr.score(X_test, y_test)
# Out:
# 1.0

# %%
lcv = LarsCV()

scores1 = [lcv.fit(train_pca[train], target[train]).score(train_pca[test], target[test])
          for train, test in kf]
scores2 = [etr.fit(train_pca[train], target[train]).score(train_pca[test], target[test])
          for train, test in kf]
scores3 = [lr.fit(train_pca[train], target[train]).score(train_pca[test], target[test])
          for train, test in kf]
scores4 = [omp.fit(train_pca[train], target[train]).score(train_pca[test], target[test])
          for train, test in kf]

all_scores = [scores1, scores2, scores3, scores4]

for score_set in all_scores:
    print('avg: %s' % (sum(score_set)/len(score_set)))
    for score in score_set:
        print score
    print(' ')
# Out:
# avg: 0.0583999416906
# 0.0972373640394
# -0.0749946234543
# 0.0187142710158
# 0.197897476742
# 0.246373934614
# -0.134828772813
#
# avg: -0.00830183351089
# 0.293189472762
# 0.0305411290519
# -0.0194574010736
# -0.468920003166
# 0.314554454315
# -0.199718652954
#
# avg: 0.0182662114512
# 0.0955234989982
# -0.177321995666
# 0.0272892017528
# 0.181931762483
# 0.239004105696
# -0.256829304556
#
# avg: 0.0436006608563
# 0.174696949514
# -0.174234789564
# -0.025515706675
# 0.229559847954
# 0.278392415987
# -0.221294752078

# %%
lcv = LarsCV()

scores1 = [lcv.fit(attr.ix[train], target[train]).score(attr.ix[test], target[test])
          for train, test in kf]
scores2 = [etr.fit(attr.ix[train], target[train]).score(attr.ix[test], target[test])
          for train, test in kf]
scores3 = [lr.fit(attr.ix[train], target[train]).score(attr.ix[test], target[test])
          for train, test in kf]
scores4 = [omp.fit(attr.ix[train], target[train]).score(attr.ix[test], target[test])
          for train, test in kf]

all_scores = [scores1, scores2, scores3, scores4]

for score_set in all_scores:
    print('avg: %s' % (sum(score_set)/len(score_set)))
    for score in score_set:
        print score
    print(' ')
# Out:
# avg: 0.0265097677545
# 0.0624747172014
# -0.0709834352329
# 0.000372231832406
# 0.149703219956
# 0.111799234115
# -0.0943073613449
#
# avg: -0.232344413038
# 0.221493285812
# -1.51124458697
# 0.133252263533
# -0.379813806608
# 0.27987803961
# -0.137631673608
#
# avg: -2.44157358566
# -1.12425188686
# -5.97935052105
# -3.80505498494
# -0.619512936981
# -0.520697508898
# -2.60057367526
#
# avg: -0.0648214936006
# 0.163096904706
# -0.54956554835
# -0.0808809647744
# 0.185888764189
# 0.254432869177
# -0.361900986551

# %%
feature_num = 1
plt.scatter(X_train[:, feature_num], predicted_train, c='g', alpha=0.5)
plt.scatter(X_test[:, feature_num], predicted_test, c='r', alpha=0.2)

# %%
clf1 = LarsCV()
clf1.fit(train_pca, target)
predictions = clf1.predict(test_pca)

# %%
submission = pd.DataFrame({'Prediction': predictions})
submission.to_csv('submission.csv', index_label='Id')
